# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar los datos
data = pd.read_csv('GCLP_All.csv')

# Convertir la columna de fecha a datetime para extraer el mes y el año
data['dateTime'] = pd.to_datetime(data['dateTime'])
data['year_month'] = data['dateTime'].dt.to_period('M')

# Agrupar por año-mes y categoría de volumen, contando las ocurrencias
monthly_volume = data.groupby(['year_month', 'volume_group']).size().unstack(fill_value=0).reset_index()

# Convertir el 'year_month' de Period a String para visualización
monthly_volume['year_month'] = monthly_volume['year_month'].astype(str)

# Crear un gráfico de barras
plt.figure(figsize=(14, 7))
monthly_volume.set_index('year_month').plot(kind='bar', stacked=False, width=0.8)
plt.title('Clasificación de Volumen por Mes')
plt.xlabel('Mes')
plt.ylabel('Cantidad')
plt.legend(title='Volumen Group')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Es la combinación de arrivals y departures
#
#
# volume_group:
#
# Esta variable parece ser una combinación de las dos anteriores o una medida general del volumen de tráfico en el aeropuerto, incluyendo tanto llegadas como salidas.
# Es posible que esta variable agregue los totales de llegadas y salidas para dar una idea general del volumen de tráfico aéreo en el aeropuerto.
